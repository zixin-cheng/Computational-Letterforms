# %%
import random
import math

# %%
html_tmpl = """<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="utf-8">
    <title>{title}</title>
    <style>
    html {{ min-height: 32em; overflow: hidden; }}
    </style>
</head>
<body>
{content}
</body>
</html>"""

from IPython.display import display, HTML
def show_html(src):
    return display(HTML(src), metadata=dict(isolated=True))

# %%
def mkdiv(content, **kwargs): #creating new function mkdiv
    if 'position' not in kwargs:
        kwargs['position'] = 'absolute'
    style_str = ' '.join([": ".join((k.replace('_', '-'), v))+";" for k, v in kwargs.items()])
    return f"<div style='{style_str}'>{content}</div>"

# %%
src = '''无言独上西楼，
月如钩，
寂寞梧桐深院锁清秋。
剪不断，
理还乱，
是离愁，
别是一般滋味在心头。'''
divs = []
for ch in src:
    this_div = mkdiv(ch,
                     position="absolute",
                     top=f"{random.randrange(25, 75)}%",
                     left=f"{random.randrange(25, 75)}%",
                     font_size="16pt")
    divs.append(this_div)
html_src = html_tmpl.format(title="exploded characters", content="".join(divs))
show_html(html_src)
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="utf-8">
#     <title>exploded characters</title>
#     <style>
#     html { min-height: 32em; overflow: hidden; }
#     </style>
# </head>
# <body>
# <div style='position: absolute; top: 59%; left: 39%; font-size: 16pt;'>无</div><div style='position: absolute; top: 45%; left: 33%; font-size: 16pt;'>言</div><div style='position: absolute; top: 31%; left: 49%; font-size: 16pt;'>独</div><div style='position: absolute; top: 38%; left: 64%; font-size: 16pt;'>上</div><div style='position: absolute; top: 65%; left: 67%; font-size: 16pt;'>西</div><div style='position: absolute; top: 47%; left: 42%; font-size: 16pt;'>楼</div><div style='position: absolute; top: 72%; left: 74%; font-size: 16pt;'>，</div><div style='position: absolute; top: 25%; left: 74%; font-size: 16pt;'>
# ...

# %%
src = '''无言独上西楼，
月如钩，
寂寞梧桐深院锁清秋。
剪不断，
理还乱，
是离愁，
别是一般滋味在心头。'''
divs = []
for ch in src:
    degrees = random.randrange(0, 360)
    this_div = mkdiv(ch,
                     position="absolute",
                     top=f"{random.randrange(25, 75)}%",
                     left=f"{random.randrange(25, 75)}%",
                     font_size="16pt",
                     transform=f"translate(-50%, -50%) rotate({degrees}deg)")
    divs.append(this_div)
html_src = html_tmpl.format(title="exploded characters", content="".join(divs))
show_html(html_src)
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="utf-8">
#     <title>exploded characters</title>
#     <style>
#     html { min-height: 32em; overflow: hidden; }
#     </style>
# </head>
# <body>
# ...

# %%
this_div = mkdiv("剪不断",
                 top="50%",
                 left="50%",
                 transform="translate(-50%, -50%)",
                 font_size="72pt",
                 )

src = '''无言独上西楼，
月如钩，
寂寞梧桐深院锁清秋。

理还乱，
是离愁，
别是一般滋味在心头。'''
divs = []
for ch in src:
    degrees = random.randrange(0, 360)
    pos = [random.randrange(25, 40),random.randrange(60, 75)]
    this_div_top = mkdiv(ch,
                     position="absolute",
                     top=f"{pos[random.randrange(0, 2)]}%",
                     left=f"{random.randrange(25, 75)}%",
                     font_size="16pt",
                     transform=f"translate(-50%, -50%) rotate({degrees}deg)")
    divs.append(this_div_top)

html_src = html_tmpl.format(title="exploded characters", content="".join(divs))
html_src2 = html_tmpl.format(title="center characters", content=this_div)
show_html(f"{html_src} {html_src2}")
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="utf-8">
#     <title>exploded characters</title>
#     <style>
#     html { min-height: 32em; overflow: hidden; }
#     </style>
# </head>
# <body>
# ...

# %%
mid_src = "剪不断"
letters = list(mid_src)
current_index = 0
mid_divs = []
mid_length = 80

for i in range(len(mid_src)):
        y_pos = (mid_length / len(mid_src)/2) + (100-mid_length)/2 + (mid_length / len(mid_src)) * i
        this_div_mid = mkdiv(letters[current_index],
                             top="50%",
                             left=f"{y_pos}%",
                             font_size="32pt",
                             transform="translate(-50%, -50%)")
        mid_divs.append(this_div_mid)
        current_index += 1

src = '''无言独上西楼，
月如钩，
寂寞梧桐深院锁清秋。

理还乱，
是离愁，
别是一般滋味在心头。'''
divs = []
for ch in src:
    degrees = random.randrange(0, 360)
    pos = [random.randrange(25, 40),random.randrange(60, 75)]
    this_div_top = mkdiv(ch,
                     position="absolute",
                     top=f"{pos[random.randrange(0, 2)]}%",
                     left=f"{random.randrange(25, 75)}%",
                     font_size="16pt",
                     transform=f"translate(-50%, -50%) rotate({degrees}deg)")
    divs.append(this_div_top)

html_src = html_tmpl.format(title="exploded characters", content="".join(divs))
html_src2 = html_tmpl.format(title="center characters", content="".join(mid_divs))
show_html(f"{html_src} {html_src2}")
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="utf-8">
#     <title>exploded characters</title>
#     <style>
#     html { min-height: 32em; overflow: hidden; }
#     </style>
# </head>
# <body>
# ...

# %%
mid_src = "剪不断"
letters = list(mid_src)
current_index = 0
mid_divs = []
mid_length = 50

for i in range(len(mid_src)):
        y_pos = (mid_length / len(mid_src)/2) + (100-mid_length)/2 + (mid_length / len(mid_src)) * i
        this_div_mid = mkdiv(letters[current_index],
                             top="50%",
                             left=f"{y_pos}%",
                             font_size="32pt",
                             transform="translate(-50%, -50%)")
        mid_divs.append(this_div_mid)
        current_index += 1

src = '''无言独上西楼，
月如钩，
寂寞梧桐深院锁清秋。

理还乱，
是离愁，
别是一般滋味在心头。'''
divs = []
   
for j in range(20):
    for ch in src:
        degrees = random.randrange(0, 360)
        pos = [random.randrange(25, 40),random.randrange(60, 75)]
        this_div_top = mkdiv(ch,
                     position="absolute",
                     top=f"{pos[random.randrange(0, 2)]}%",
                     left=f"{random.randrange(25, 75)}%",
                     font_size="16pt",
                     transform=f"translate(-50%, -50%) rotate({degrees}deg)")
        divs.append(this_div_top)



html_src = html_tmpl.format(title="exploded characters", content="".join(divs))
html_src2 = html_tmpl.format(title="center characters", content="".join(mid_divs))
show_html(f"{html_src} {html_src2}")
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="utf-8">
#     <title>exploded characters</title>
#     <style>
#     html { min-height: 32em; overflow: hidden; }
#     </style>
# </head>
# <body>
# ...

# %%
mid_src = "剪不断"
letters = list(mid_src)
current_index = 0
mid_divs = []
mid_length = 50

for i in range(len(mid_src)):
        y_pos = (mid_length / len(mid_src)/2) + (100-mid_length)/2 + (mid_length / len(mid_src)) * i
        this_div_mid = mkdiv(letters[current_index],
                             top="50%",
                             left=f"{y_pos}%",
                             font_size="16pt",
                             color= "red",
                             transform="translate(-50%, -50%)")
        mid_divs.append(this_div_mid)
        current_index += 1

src = '''无言独上西楼，
月如钩，
寂寞梧桐深院锁清秋。

理还乱，
是离愁，
别是一般滋味在心头。'''
divs = []
   
for j in range(20):
    for ch in src:
        degrees = random.randrange(0, 360)
        pos = random.randrange(25, 75)
        this_div_top = mkdiv(ch,
                     position="absolute",
                     top=f"{pos}%",
                     left=f"{random.randrange(25, 75)}%",
                     font_size="16pt",
                     transform=f"translate(-50%, -50%) rotate({degrees}deg)")
        divs.append(this_div_top)



html_src = html_tmpl.format(title="exploded characters", content="".join(divs))
html_src2 = html_tmpl.format(title="center characters", content="".join(mid_divs))
show_html(f"{html_src2} {html_src}")
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="utf-8">
#     <title>center characters</title>
#     <style>
#     html { min-height: 32em; overflow: hidden; }
#     </style>
# </head>
# <body>
# <div style='top: 50%; left: 33.333333333333336%; font-size: 16pt; color: red; transform: translate(-50%, -50%); position: absolute;'>剪</div><div style='top: 50%; left: 50.0%; font-size: 16pt; color: red; transform: translate(-50%, -50%); position: absolute;'>不</div><div style='top: 50%; left: 66.66666666666667%; font-size: 16pt; color: red; transform: translate(-50%, -50%); position: absolute;'>断</div>
# </body>
# </html> <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="utf-8">
#     <title>exploded characters</title>
#     <style>
#     html { min-height: 32em; overflow: hidden; }
#     </style>
# </head>
# <body>
# ...

# %%
mid_src = '''无言独上西楼，
月如钩，
寂寞梧桐深院锁清秋。
剪不断，
理还乱，
是离愁，
别是一般滋味在心头。'''
mid_divs = []
row = 1
col = 0

for i in range(len(src)):
        ch = mid_src[i]
        x_pos = 10 + 5 * row
        y_pos = 75 - 10 * col
        row += 1
        if ch == "，" or ch == "。":
            col += 1
            row = 0
            
        this_div_mid = mkdiv(ch,
                             top=f"{x_pos}%",
                             left=f"{y_pos}%",
                             font_size="16pt",
                             writing_mode= "vertical-rl",
                             text_orientation= "upright",
                             transform="translate(-50%, -50%)")
        mid_divs.append(this_div_mid)
        
html_src = html_tmpl.format(title="exploded characters", content="".join(mid_divs))
show_html(html_src)
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="utf-8">
#     <title>exploded characters</title>
#     <style>
#     html { min-height: 32em; overflow: hidden; }
#     </style>
# </head>
# <body>
# ...

# %%
mid_src = '''无言独上西楼，
月如钩，
寂寞梧桐深院锁清秋。
剪不断，
理还乱，
是离愁，
别是一般滋味在心头。'''
mid_divs = []
row = 1
col = 0

for i in range(len(src)):
        ch = mid_src[i]
        x_pos = 10 + 5 * row + i*random.uniform(i*0.01, i*0.015)
        y_pos = 75 - 5 * col - i*random.uniform(i*0.01, i*0.015)
        degrees = i*random.randrange(1, 5)
        row+=1
        if ch == "，" or ch == "。":
            col += 1
            row = 0
            
        this_div_mid = mkdiv(ch,
                             top=f"{x_pos}%",
                             left=f"{y_pos}%",
                             font_size="16pt",
                             writing_mode= "vertical-rl",
                             text_orientation= "upright",
                             transform=f"translate(-50%, -50%) rotate({degrees}deg)")
        mid_divs.append(this_div_mid)
        
html_src = html_tmpl.format(title="exploded characters", content="".join(mid_divs))
show_html(html_src)
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="utf-8">
#     <title>exploded characters</title>
#     <style>
#     html { min-height: 32em; overflow: hidden; }
#     </style>
# </head>
# <body>
# ...
